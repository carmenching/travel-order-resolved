# %% [markdown]
# # Find the city of each train station
# In order to find the city of each train station we need a representation of the area of each city : https://public.opendatasoft.com/explore/dataset/georef-france-commune/export/?disjunctive.reg_name&disjunctive.dep_name&disjunctive.arrdep_name&disjunctive.ze2020_name&disjunctive.bv2012_name&disjunctive.epci_name&disjunctive.ept_name&disjunctive.com_name&disjunctive.ze2010_name&disjunctive.com_is_mountain_area&refine.dep_name=Paris&location=9,42.90011,2.31812&basemap=jawg.light
#
# Here you can find a representation with the geojson format which is loadable with pandas_geojson.
#
# ```
# pip install pandas_geojson

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon

stops = pd.read_csv('data_sncf/stops.txt')

def formatID(id):
    return ''.join([i for i in id if i.isdigit()])

stops['stop_id']=stops['stop_id'].apply(formatID)
stops=stops.drop_duplicates(subset=['stop_id'])
stops=stops.dropna(subset=['stop_name'])

region = gpd.read_file('georef-france-region/georef-france-region-millesime.shp',encoding='utf-8')
region.loc[(region['reg_is_ctu']=='Non') & (region['reg_area_co']=='FXX')]
# Out:
#     year reg_code reg_current                    reg_name  \
# 0   2022       75          75          Nouvelle-Aquitaine
# 4   2022       11          11               Île-de-France
# 5   2022       32          32             Hauts-de-France
# 6   2022       24          24         Centre-Val de Loire
# 10  2022       52          52            Pays de la Loire
# 12  2022       28          28                   Normandie
# 16  2022       27          27     Bourgogne-Franche-Comté
# 17  2022       53          53                    Bretagne
# 18  2022       76          76                   Occitanie
# 21  2022       44          44                   Grand Est
# 22  2022       84          84        Auvergne-Rhône-Alpes
# 24  2022       93          93  Provence-Alpes-Côte d'Azur
#
#                    reg_name_up                 reg_name_lo reg_area_co  \
# 0           NOUVELLE AQUITAINE          nouvelle-aquitaine         FXX
# 4                ILE DE FRANCE               île-de-france         FXX
# 5              HAUTS DE FRANCE             hauts-de-france         FXX
# 6          CENTRE VAL DE LOIRE         centre-val de loire         FXX
# 10            PAYS DE LA LOIRE            pays de la loire         FXX
# 12                   NORMANDIE                   normandie         FXX
# 16     BOURGOGNE FRANCHE COMTE     bourgogne-franche-comté         FXX
# 17                    BRETAGNE                    bretagne         FXX
# 18                   OCCITANIE                   occitanie         FXX
# 21                   GRAND EST                   grand est         FXX
# 22        AUVERGNE RHONE ALPES        auvergne-rhône-alpes         FXX
# 24  PROVENCE ALPES COTE D AZUR  provence-alpes-côte d'azur         FXX
#
#    reg_type reg_is_ctu reg_siren_c  \
# 0    région        Non   200053759
# 4    région        Non   237500079
# 5    région        Non   200053742
# 6    région        Non   234500023
# 10   région        Non   234400034
# 12   région        Non   200053403
# 16   région        Non   200053726
# 17   région        Non   233500016
# 18   région        Non   200053791
# 21   région        Non   200052264
# 22   région        Non   200053767
# 24   région        Non   231300021
#
#                                              geometry
# 0   MULTIPOLYGON (((-1.41248 46.18439, -1.46313 46...
# 4   POLYGON ((3.48502 48.85185, 3.48518 48.82524, ...
# 5   POLYGON ((3.48502 48.85185, 3.45213 48.85614, ...
# 6   POLYGON ((1.50140 48.94103, 1.50734 48.92757, ...
# 10  MULTIPOLYGON (((-2.33743 46.71910, -2.31817 46...
# 12  POLYGON ((1.70435 49.23243, 1.67469 49.21166, ...
# 16  POLYGON ((2.93662 48.16346, 2.94025 48.18297, ...
# 17  MULTIPOLYGON (((-3.42742 47.64103, -3.41803 47...
# 18  MULTIPOLYGON (((-0.07520 43.30716, -0.11063 43...
# 21  POLYGON ((3.41474 48.39019, 3.42247 48.41270, ...
# 22  POLYGON ((2.28109 46.42047, 2.28335 46.44948, ...
# 24  MULTIPOLYGON (((6.50637 43.04378, 6.48911 43.0...

# %% [markdown]
# The coordinates are inverted for Audun le roman.

# %%
lat=stops.loc[stops['stop_name']=='Audun-le-Roman-JJ.','stop_lat'][2388]
lon=stops.loc[stops['stop_name']=='Audun-le-Roman-JJ.','stop_lon'][2388]
stops.loc[stops['stop_name']=='Audun-le-Roman-JJ.','stop_lon']=lat
stops.loc[stops['stop_name']=='Audun-le-Roman-JJ.','stop_lat']=lon

# %% [markdown]
# Here is a function to find the region of each station in the dataframe. A similar function will be used to find in which departement and communes are the stations.

# %%
def where(row,areas):
    p=Point(row['stop_lon'],row['stop_lat'])
    m=areas.apply(lambda x: p.within(x['geometry']),axis=1)
    r=areas[m].reg_name.sum()
    return r

# %% [markdown]
# Let's apply this function to create a new region column for each stop.

# %%
stops['region']=stops.apply(lambda x : where(x,region),axis=1)

# %%
stops['region']
# Out:
# 0                 Île-de-France
# 1                     Normandie
# 2                     Normandie
# 3                     Normandie
# 4                     Normandie
#                  ...
# 3831    Bourgogne-Franche-Comté
# 3832    Bourgogne-Franche-Comté
# 3833    Bourgogne-Franche-Comté
# 3834    Bourgogne-Franche-Comté
# 3835                   Bretagne
# Name: region, Length: 3834, dtype: object

# %%
dpt = gpd.read_file('georef-france-departement-millesime/georef-france-departement-millesime.shp',encoding='utf-8')
dpt=dpt.loc[dpt['year']=='2022']

# %%
def wheredpt(row):
    p=Point(row['stop_lon'],row['stop_lat'])
    dep=dpt.loc[dpt['reg_name']==row['region']]
    m=dep.apply(lambda x: p.within(x['geometry']),axis=1)
    r=dep[m].dep_name.sum()
    return r

stops['dpt']=stops.apply(wheredpt,axis=1)

# %%
stops.loc[stops['region']=='Occitanie']
# Out:
#        stop_id                        stop_name  stop_desc   stop_lat  \
# 167   87784686  Gare de Villefranche-Vernet-l.B        NaN  42.591468
# 168   87784702                 Gare de Serdinya        NaN  42.567048
# 169   87784710                   Gare de Joncet        NaN  42.561757
# 170   87784728  Gare de Olette-Canaveilles-l.B.        NaN  42.554664
# 171   87784736                    Gare de Nyers        NaN  42.542267
# ...        ...                              ...        ...        ...
# 3721  87781542     Gare de Ceilhes-Roqueredonde        NaN  43.812131
# 3722  87781559              Gare de Les Cabrils        NaN  43.778965
# 3723  87781575                    Gare de Lunas        NaN  43.710023
# 3724  87781583        Gare de Le Bousquet-d'Orb        NaN  43.691547
# 3725  87783340      Gare de Campagnac-St-Geniez        NaN  44.422134
#
#       stop_lon  zone_id  stop_url  location_type parent_station     region  \
# 167   2.370015      NaN       NaN              1            NaN  Occitanie
# 168   2.323390      NaN       NaN              1            NaN  Occitanie
# 169   2.311354      NaN       NaN              1            NaN  Occitanie
# 170   2.272553      NaN       NaN              1            NaN  Occitanie
# 171   2.262999      NaN       NaN              1            NaN  Occitanie
# ...        ...      ...       ...            ...            ...        ...
# 3721  3.155299      NaN       NaN              1            NaN  Occitanie
# 3722  3.186163      NaN       NaN              1            NaN  Occitanie
# 3723  3.194443      NaN       NaN              1            NaN  Occitanie
# 3724  3.168385      NaN       NaN              1            NaN  Occitanie
# 3725  3.066130      NaN       NaN              1            NaN  Occitanie
#
#                       dpt
# 167   Pyrénées-Orientales
# 168   Pyrénées-Orientales
# 169   Pyrénées-Orientales
# 170   Pyrénées-Orientales
# 171   Pyrénées-Orientales
# ...                   ...
# 3721              Hérault
# 3722              Hérault
# 3723              Hérault
# 3724              Hérault
# 3725              Aveyron
#
# [348 rows x 11 columns]

# %%
communes=gpd.read_file('georef-france-commune.geojson',encoding='utf-8')

# %%
stops
# Out:
#        stop_id                  stop_name  stop_desc   stop_lat  stop_lon  \
# 0     87381509    Gare de Mantes-la-Jolie        NaN  48.989687  1.703294
# 1     87415604     Gare de Vernon-Giverny        NaN  49.091286  1.478363
# 2     87415620   Gare de Gaillon-Aubevoye        NaN  49.174632  1.352518
# 3     87415877       Gare de Val-de-Reuil        NaN  49.275399  1.224609
# 4     87411207             Gare de Oissel        NaN  49.343042  1.101821
# ...        ...                        ...        ...        ...       ...
# 3831  87718403  Gare de Roche-lez-Beaupré        NaN  47.276417  6.111272
# 3832  87718411          Gare de Novillars        NaN  47.283906  6.132791
# 3833  87718429              Gare de Deluz        NaN  47.292454  6.199545
# 3834  87718437            Gare de Laissey        NaN  47.298881  6.233690
# 3835  87471607           Gare de Fougères        NaN  48.350290 -1.194508
#
#       zone_id  stop_url  location_type parent_station  \
# 0         NaN       NaN              1            NaN
# 1         NaN       NaN              1            NaN
# 2         NaN       NaN              1            NaN
# 3         NaN       NaN              1            NaN
# 4         NaN       NaN              1            NaN
# ...       ...       ...            ...            ...
# 3831      NaN       NaN              1            NaN
# 3832      NaN       NaN              1            NaN
# 3833      NaN       NaN              1            NaN
# 3834      NaN       NaN              1            NaN
# 3835      NaN       NaN              1            NaN
#
#                        region              dpt
# 0               Île-de-France         Yvelines
# 1                   Normandie             Eure
# 2                   Normandie             Eure
# 3                   Normandie             Eure
# 4                   Normandie   Seine-Maritime
# ...                       ...              ...
# 3831  Bourgogne-Franche-Comté            Doubs
# 3832  Bourgogne-Franche-Comté            Doubs
# 3833  Bourgogne-Franche-Comté            Doubs
# 3834  Bourgogne-Franche-Comté            Doubs
# 3835                 Bretagne  Ille-et-Vilaine
#
# [3834 rows x 11 columns]

# %%
def wherecom(row):
    p=Point(row['stop_lon'],row['stop_lat'])
    com=communes.loc[communes['dep_name']==row['dpt']]
    m=com.apply(lambda x: p.within(x['geometry']),axis=1)
    r=com[m].com_name.sum()
    return r

stops['communes']=stops.apply(wherecom,axis=1)

# %%
stops
# Out:
#        stop_id                  stop_name  stop_desc   stop_lat  stop_lon  \
# 0     87381509    Gare de Mantes-la-Jolie        NaN  48.989687  1.703294
# 1     87415604     Gare de Vernon-Giverny        NaN  49.091286  1.478363
# 2     87415620   Gare de Gaillon-Aubevoye        NaN  49.174632  1.352518
# 3     87415877       Gare de Val-de-Reuil        NaN  49.275399  1.224609
# 4     87411207             Gare de Oissel        NaN  49.343042  1.101821
# ...        ...                        ...        ...        ...       ...
# 3831  87718403  Gare de Roche-lez-Beaupré        NaN  47.276417  6.111272
# 3832  87718411          Gare de Novillars        NaN  47.283906  6.132791
# 3833  87718429              Gare de Deluz        NaN  47.292454  6.199545
# 3834  87718437            Gare de Laissey        NaN  47.298881  6.233690
# 3835  87471607           Gare de Fougères        NaN  48.350290 -1.194508
#
#       zone_id  stop_url  location_type parent_station  \
# 0         NaN       NaN              1            NaN
# 1         NaN       NaN              1            NaN
# 2         NaN       NaN              1            NaN
# 3         NaN       NaN              1            NaN
# 4         NaN       NaN              1            NaN
# ...       ...       ...            ...            ...
# 3831      NaN       NaN              1            NaN
# 3832      NaN       NaN              1            NaN
# 3833      NaN       NaN              1            NaN
# 3834      NaN       NaN              1            NaN
# 3835      NaN       NaN              1            NaN
#
#                        region              dpt           communes
# 0               Île-de-France         Yvelines    Mantes-la-Jolie
# 1                   Normandie             Eure             Vernon
# 2                   Normandie             Eure     Le Val d'Hazey
# 3                   Normandie             Eure       Val-de-Reuil
# 4                   Normandie   Seine-Maritime             Oissel
# ...                       ...              ...                ...
# 3831  Bourgogne-Franche-Comté            Doubs  Roche-lez-Beaupré
# 3832  Bourgogne-Franche-Comté            Doubs          Novillars
# 3833  Bourgogne-Franche-Comté            Doubs              Deluz
# 3834  Bourgogne-Franche-Comté            Doubs            Laissey
# 3835                 Bretagne  Ille-et-Vilaine           Fougères
#
# [3834 rows x 12 columns]

# %% [markdown]
# Some stops like the ones that are near the sea are not in the communes area defined by the opendatasoft dataset, so we will set the 'communes' value as the 'stop_name' value after 'Gare de '

# %%
missing=stops[stops['communes']==0]

# %%
com=communes['com_name'].tolist()

# %% [markdown]
# Some of the stations don't seems to be in france as the communes after "Gare de " is not in our dataset. Here we can see Monaco-Monte-Carlo is not in France but in Monaco.

# %%
m=missing["stop_name"].map(lambda x: x.replace("Gare de ","") not in com)
missing[m]
# Out:
#        stop_id                        stop_name  stop_desc   stop_lat  \
# 238   87756403       Gare de Monaco-Monte-Carlo        NaN  43.738483
# 239   87756478                 Gare de Carnolès        NaN  43.761986
# 260   85010082                   Gare de Genève        NaN  46.210558
# 333   87598219  Gare de Le Locle-Col-des-Roches        NaN  47.049890
# 334   85043166                 Gare de Le Locle        NaN  47.057880
# ...        ...                              ...        ...        ...
# 2555  85010009                  Gare de Zimeysa        NaN  46.221260
# 2556  85010066           Gare de Vernier-Meyrin        NaN  46.220734
# 2557  85010074                  Gare de Vernier        NaN  46.220707
# 2750  87734343              Gare de Chapeauroux        NaN  44.838075
# 3021  87592717        Gare de Saillat-Chassenon        NaN  45.869510
#
#       stop_lon  zone_id  stop_url  location_type parent_station  \
# 238   7.419670      NaN       NaN              1            NaN
# 239   7.481441      NaN       NaN              1            NaN
# 260   6.143155      NaN       NaN              1            NaN
# 333   6.725831      NaN       NaN              1            NaN
# 334   6.746129      NaN       NaN              1            NaN
# ...        ...      ...       ...            ...            ...
# 2555  6.065743      NaN       NaN              1            NaN
# 2556  6.093892      NaN       NaN              1            NaN
# 2557  6.093890      NaN       NaN              1            NaN
# 2750  3.741826      NaN       NaN              1            NaN
# 3021  0.811922      NaN       NaN              1            NaN
#
#                           region          dpt communes
# 238   Provence-Alpes-Côte d'Azur            0        0
# 239                            0            0        0
# 260                            0            0        0
# 333                            0            0        0
# 334                            0            0        0
# ...                          ...          ...      ...
# 2555                           0            0        0
# 2556                           0            0        0
# 2557                           0            0        0
# 2750        Auvergne-Rhône-Alpes  Haute-Loire        0
# 3021          Nouvelle-Aquitaine     Charente        0
#
# [111 rows x 12 columns]

# %% [markdown]
# There does not seem to be any stations in those 111 stations that are not in the city after "Gare de " so we can make the communes column equal to the city.

# %%
stops.loc[stops['communes']==0,'communes']=stops[stops['communes']==0]["stop_name"].map(lambda x: x.replace("Gare de ",""))

# %% [markdown]
# # Add area in Neo4J

# %%
region.to_csv('region.csv')

# %%
dpt.to_csv('departement.csv')

# %%
communes['station']=communes.apply(lambda x : stops.loc[stops['communes']==x['com_name'],'stop_name'].tolist(), axis=1)

# %%
communes.to_csv('communes.csv')

# %%
stops.to_csv('station.csv')

# %% [markdown]
# ### Were are going to had the region and the departements in Neo4j as it will be needed to differentiate communes with the same name and eventually to implement pathfinding with geolocalisation.
# Add csv in dbms import directory
#
# Region :
#
# ```
# LOAD CSV WITH HEADERS FROM "file:///region.csv" AS row
# MERGE (r:Region:Area {name: row.reg_name, code: row.reg_code, geometry: row.geometry})
# ```
#
# Departement :
#
# ```
# LOAD CSV WITH HEADERS FROM "file:///departement.csv" AS row
# Match (r:Region {name: row.reg_name})
# MERGE (d:Departement:Area {name: row.dep_name, code: row.dep_code, geometry: row.geometry})
# Merge (d)-[:IS_IN]-(r)
# ```
#
# Communes:
#
# ```
# LOAD CSV WITH HEADERS FROM "file:///communes.csv" AS row
# Match (d:Departement{name: row.dep_name})
# MERGE (c:Communes:Area {name: row.com_name, geometry: row.geometry})
# Merge (c)-[:IS_IN]-(d)
# ```
#
# ```
# LOAD CSV WITH HEADERS FROM "file:///station.csv" AS row
# merge (s:Station {name: row.stop_name, lat:toFloat(row.stop_lat),lon:toFloat(row.stop_lon), id:row.stop_id, location_type:row.location_type}) With s, row
# Match (c:Communes {name: row.communes})-[IS_IN]-(d:Departement {name:row.dpt})
# Merge (c)-[:HAS_TRAIN_STATION]-(s)
# ```
